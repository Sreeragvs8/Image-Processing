# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import glob 
from sklearn.utils import shuffle 
from skimage.transform import resize

# %%
pwd
# Out:
# 'C:\\Users\\sreer\\Edure\\Data Science\\Image processing\\Tomato and apple classification'

# %%
tomato = glob.glob('train/apples/*.jpeg')
apple = glob.glob('train/tomatoes/*.jpeg')

# %%
len(tomato)
# Out:
# 164

# %%
len(apple)
# Out:
# 130

# %%
len(tomato_test)
# Out:
# 43

# %%
len(apple_test)
# Out:
# 54

# %%
image =[] 
label =[] 

for i in tomato: 
    img = plt.imread(i)
    image.append(img)
    label.append(0)

for i in apple: 
    img= plt.imread(i)
    image.append(img)
    label.append(1)

# %%
plt.figure(figsize = (10,8))
for i in range(12):
    plt.subplot(3,4,i+1)
    plt.imshow(image[i])
plt.tight_layout()

# %%
image, label = shuffle(image, label)

# %%
plt.figure(figsize = (10,8))
for i in range(12):
    plt.subplot(3,4,i+1)
    plt.imshow(image[i])
plt.tight_layout()

# %%
# plot image
plt.figure(figsize=(10, 10))  
for i in range(20):
    plt.subplot(4,5,i+1)
    plt.imshow(image[i])
plt.tight_layout()

# %%
for i in range(10):
    print(image[i].shape)
# Out:
# (184, 275, 3)
# (173, 290, 3)
# (183, 275, 3)
# (183, 275, 3)
# (100, 100, 3)
# (194, 259, 3)
# (194, 259, 3)
# (225, 225, 3)
# (196, 196, 3)
# (100, 100, 3)

# %%
X = []

for i in image:
    X.append(resize(i, (500,500,3)))

# %%
X = np.array(X)

# %%
y = np.array(label)

# %%
d1, d2, d3, d4 = X.shape

# %%
X = X.reshape((d1, d2*d3*d4))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
# %time model.fit(X_train, y_train)
# Out:
# CPU times: total: 9.05 s
# Wall time: 17.3 s
# SVC()

# %%
# %time y_pred = model.predict(X_test)
# Out:
# CPU times: total: 8.95 s
# Wall time: 37.5 s

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6101694915254238
